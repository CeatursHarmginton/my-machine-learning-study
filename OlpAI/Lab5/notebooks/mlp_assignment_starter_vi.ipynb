# %% [markdown]
# # Notebook khởi đầu: Chuỗi bài thực hành MLP
#
# Hoàn thành các ô TODO. Notebook lời giải mẫu nằm ở `mlp_assignment_solutions_vi.ipynb`.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

import torch
# Giới hạn số luồng để notebook chạy nhanh và ổn định trên máy cá nhân/lab.
torch.set_num_threads(1)
torch.set_num_interop_threads(1)
from torch import nn
from torch.utils.data import TensorDataset, DataLoader

SEED = 42
np.random.seed(SEED)
torch.manual_seed(SEED)
DATA_DIR = Path('../datasets')

def metrics(y_true, y_pred):
    # TODO: trả về MSE, RMSE, MAE, R2
    pass

# %% [markdown]
# ## Hoạt động 1 - So sánh Linear, Polynomial và MLP

# %%
df = pd.read_csv(DATA_DIR/'activity_01_piecewise_nonlinear_1d.csv')
# TODO 1: vẽ scatter plot giữa x và y
# TODO 2: huấn luyện Linear Regression
# TODO 3: huấn luyện Polynomial Regression bậc 2, 3, 5
# TODO 4: huấn luyện MLP
# TODO 5: tạo bảng so sánh chỉ số đánh giá

# %% [markdown]
# ## Hoạt động 2 - Trực quan hóa activation của nơ-ron

# %%
df2 = pd.read_csv(DATA_DIR/'activity_02_relu_basis_1d.csv')
# TODO: huấn luyện MLP một lớp ẩn và trích xuất z, activation a, contribution của từng nơ-ron

# %% [markdown]
# ## Hoạt động 3 - Thí nghiệm kiến trúc

# %%
df3 = pd.read_csv(DATA_DIR/'activity_03_architecture_experiment_1d.csv')
# TODO: thử nhiều kiến trúc MLP, ghi lại số tham số, train RMSE, test RMSE

# %% [markdown]
# ## Hoạt động 4 - Động học học qua epoch

# %%
df4 = pd.read_csv(DATA_DIR/'activity_04_learning_dynamics_1d.csv')
# TODO: lưu checkpoint tại nhiều epoch và vẽ prediction curve qua thời gian

# %% [markdown]
# ## Hoạt động 5 - MLP nhiều đầu vào

# %%
df5 = pd.read_csv(DATA_DIR/'activity_05_multivariate_surface_2d.csv')
# TODO: huấn luyện Linear, Polynomial, MLP và vẽ heatmap dự báo trên mặt phẳng x1, x2

# %% [markdown]
# ## Hoạt động 6 - Dữ liệu nhiều biến

# %%
df6 = pd.read_csv(DATA_DIR/'activity_06_high_dimensional_mlp.csv')
# TODO: so sánh Linear, Ridge, Lasso, Elastic Net và MLP
# TODO: kiểm tra hệ số Lasso và permutation importance cho MLP
